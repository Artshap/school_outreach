# %% [markdown]
# <a href="https://colab.research.google.com/github/Artshap/school_outreach/blob/master/Australian_Mineral_and_Energy_Resources.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ACKNOWLEDGEMENT: This module is based on "Global Petroleum Resources" lab by Tristan Salles
#
# https://geoslearn.github.io/index.html

# %%
#@title Required Packages installation and Files Downloading.
# %%capture

# !apt-get install libgeos-3.5.0
# !apt-get install libgeos-dev
# !pip install https://github.com/matplotlib/basemap/archive/master.zip
# !git clone https://github.com/tristan-salles/SedBasinLabs.git
# !git clone https://github.com/Artshap/school_outreach.git

# %%
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.cm as cm
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon
from matplotlib.collections import PatchCollection
from matplotlib.patches import PathPatch
from pylab import rcParams
import warnings
from math import log
from IPython.display import YouTubeVideo

# %% [markdown]
# # Australian Mineral Resources

# %% [markdown]
# > ![alt text](https://github.com/Artshap/school_outreach/blob/master/Module_1/Figures/1.png?raw=true)
#
#
#
# Australia has the world’s greatest resources of Gold, Iron Ore, Lead, Nickel, Rutile, Tantalum, Uranium, Zinc and Zircon. Australia is the number one producer of Bauxite, Iron Ore, Lithium and Rutile, and is in the top five for 17 commodities in total. Australia’s mineral exports amounted to a staggering \$179B in 2017 which was 8.1% of GDP. The mining industry employed over 220000 people. The majority of our export income was accounted for by iron ore, black coal, gold, aluminium and copper which combined grossed $157B.
# Expanding exploration efforts have focused on minerals and commodities which are critical for the development of emerging technologies such as battery storage, renewable energy and electric vehicles.
#
# ![alt text](https://github.com/Artshap/school_outreach/blob/master/Module_1/Figures/2_1.png?raw=true)
# ![alt text](https://github.com/Artshap/school_outreach/blob/master/Module_1/Figures/2_2.png?raw=true)
# ![alt text](https://github.com/Artshap/school_outreach/blob/master/Module_1/Figures/2_3.png?raw=true)

# %% [markdown]
# ## Bauxite
#
# Australia’s EDR of bauxite was estimated to be 6015Mt in 2017, we were also the world’s leading producer. The majority of Australia’s bauxite can be found in three locations, Cape York in Queensland (3155Mt, 52% of National EDR), Darling Range in Western Australia (2634Mt, 44%) and  Gove in the Northern Territory (185Mt, 3%). Australia had 2170Mt of Ore reserves in 2017 with seven operating mines accounting for 813Mt (37%). 88Mt of bauxite was produced by these mines in 2017.

# %%
fig     = plt.figure(figsize=(10,10))
ax      = fig.add_subplot(111)

map = Basemap(llcrnrlon=100,llcrnrlat=-50,urcrnrlon=180,urcrnrlat=10.,
             resolution='l', projection='merc', lat_0 = 39.5, lon_0 = 1)

map.drawmapboundary(fill_color='aqua')
map.fillcontinents(color='#C0C0C0') #,lake_color='aqua')
map.drawcoastlines()
map.drawparallels(np.arange(-80,81,20),labels=[1,0,0,0], fontsize=10)
map.drawmeridians(np.arange(-180,180,20),labels=[0,0,0,1], fontsize=10)
map.readshapefile('/content/school_outreach/Module_1/Shapefiles/converted/Bauxite_converted', 'Bauxite',drawbounds = True)



patches   = []

for info, shape in zip(map.Bauxite, map.Bauxite):
  patches.append( Polygon(np.array(shape), True) )

ax.add_collection(PatchCollection(patches, facecolor= '#665e5a', edgecolor='k', linewidths=1., zorder=2))


plt.show()

# %% [markdown]
# ## Copper
#
# Australia’s EDR of copper in 2017 was 87.47Mt. South Australia has 65% of Australia’s copper resources with the majority in the Olympic Dam deposit which contains 59% of Australia’s EDR. New South Wales only has 15% of total EDR followed by Queensland with 13%. Australia had 23.03Mt of copper ore reserves in 2017. 20.08Mt (87%) is attributable to 35 operating mines. Total production in 2017 was 0.86Mt .

# %%
fig     = plt.figure(figsize=(10,10))
ax      = fig.add_subplot(111)

map = Basemap(llcrnrlon=100,llcrnrlat=-50,urcrnrlon=180,urcrnrlat=10.,
             resolution='l', projection='merc', lat_0 = 39.5, lon_0 = 1)

map.drawmapboundary(fill_color='aqua')
map.fillcontinents(color='#C0C0C0') #,lake_color='aqua')
map.drawcoastlines()
map.drawparallels(np.arange(-80,81,20),labels=[1,0,0,0], fontsize=10)
map.drawmeridians(np.arange(-180,180,20),labels=[0,0,0,1], fontsize=10)
map.readshapefile('/content/school_outreach/Module_1/Shapefiles/converted/Copper_converted', 'Copper',drawbounds = True)



patches   = []

for info, shape in zip(map.Copper, map.Copper):
  patches.append( Polygon(np.array(shape), True) )

ax.add_collection(PatchCollection(patches, facecolor= '#b87333', edgecolor='k', linewidths=1., zorder=2))


plt.show()

# %% [markdown]
# ## Gold

# %% [markdown]
# Gold was extracted from 128 mines in 2017. Gold reserves and resources are dominated by multi-element deposits such as copper, silver and gold. The majority of gold produced (203 of 292t, 70%) comes from lode-gold which is where gold is deposited with metaliferous ore which fills the fissures in rock formations. At the current rate of production, lode-gold deposits have an average reserve life of only five years and a resource life of ten. There was 2903t of gold ore reserves as of 31 december 2017 with measured and indicated mineral resources being 6702t. Production is 292t per year giving gold 10 years of reserve life.

# %%
YouTubeVideo('RnDQi2DD8ik')

# %%
fig     = plt.figure(figsize=(10,10))
ax      = fig.add_subplot(111)

map = Basemap(llcrnrlon=100,llcrnrlat=-50,urcrnrlon=180,urcrnrlat=10.,
             resolution='l', projection='merc', lat_0 = 39.5, lon_0 = 1)

map.drawmapboundary(fill_color='aqua')
map.fillcontinents(color='#C0C0C0') #,lake_color='aqua')
map.drawcoastlines()
map.drawparallels(np.arange(-80,81,20),labels=[1,0,0,0], fontsize=10)
map.drawmeridians(np.arange(-180,180,20),labels=[0,0,0,1], fontsize=10)
map.readshapefile('/content/school_outreach/Module_1/Shapefiles/converted/Gold_converted', 'Gold',drawbounds = True)



patches   = []

for info, shape in zip(map.Gold, map.Gold):
  patches.append( Polygon(np.array(shape), True) )

ax.add_collection(PatchCollection(patches, facecolor= 'gold', edgecolor='k', linewidths=1., zorder=2))


plt.show()

# %% [markdown]
# ## Iron ore
#
# Australia has significant deposits of both hematite and magnetite with the Economic Demonstrated Resources (EDR) estimated to be 47,987 Million tonnes. Western Australia has 92% of Australia’s EDR of iron ore, with almost 80% residing in the Hamersley Province. Australia has 24,146 Mt of iron ore reserves, 28% of the world’s iron ore. There are 33 operating mines which produced 883Mt in 2017, Western Australia produced 99% of this total.

# %%
fig     = plt.figure(figsize=(10,10))
ax      = fig.add_subplot(111)

map = Basemap(llcrnrlon=100,llcrnrlat=-50,urcrnrlon=180,urcrnrlat=10.,
             resolution='l', projection='merc', lat_0 = 39.5, lon_0 = 1)

map.drawmapboundary(fill_color='aqua')
map.fillcontinents(color='#C0C0C0') #,lake_color='aqua')
map.drawcoastlines()
map.drawparallels(np.arange(-80,81,20),labels=[1,0,0,0], fontsize=10)
map.drawmeridians(np.arange(-180,180,20),labels=[0,0,0,1], fontsize=10)
map.readshapefile('/content/school_outreach/Module_1/Shapefiles/converted/Iron_converted', 'Iron',drawbounds = True)



patches   = []

for info, shape in zip(map.Iron, map.Iron):
  patches.append( Polygon(np.array(shape), True) )

ax.add_collection(PatchCollection(patches, facecolor= '#50676b', edgecolor='k', linewidths=1., zorder=2))


plt.show()

# %% [markdown]
# ## Zinc
#
# Zinc typically occurs with lead in many mineral deposits due to their similar geochemical behaviours in hydrothermal fluids. In 2017 zinc had 67.52Mt of EDR. Queensland had the majority of Australia’s zinc resources at 60% mainly in the Mount Isa region, followed by Northern Territory with 27% mainly in the McArthur River mine. Australia is the 5th largest producer of zinc in the world with reserves of 25.3Mt in 2017. 12 operating mines accounted for 18.54Mt (73%) of EDR and produced 0.841Mt of zinc.

# %%
fig     = plt.figure(figsize=(10,10))
ax      = fig.add_subplot(111)

map = Basemap(llcrnrlon=100,llcrnrlat=-50,urcrnrlon=180,urcrnrlat=10.,
             resolution='l', projection='merc', lat_0 = 39.5, lon_0 = 1)

map.drawmapboundary(fill_color='aqua')
map.fillcontinents(color='#C0C0C0') #,lake_color='aqua')
map.drawcoastlines()
map.drawparallels(np.arange(-80,81,20),labels=[1,0,0,0], fontsize=10)
map.drawmeridians(np.arange(-180,180,20),labels=[0,0,0,1], fontsize=10)
map.readshapefile('/content/school_outreach/Module_1/Shapefiles/converted/Zinc_converted', 'Zinc',drawbounds = True)



patches   = []

for info, shape in zip(map.Zinc, map.Zinc):
  patches.append( Polygon(np.array(shape), True) )

ax.add_collection(PatchCollection(patches, facecolor= '#6fa1d2', edgecolor='k', linewidths=1., zorder=2))


plt.show()

# %% [markdown]
# # Australian Oil and Gas Resources
# If we want to see the values for this region we need to look up the name of the fields in the attribute table;
# * Milligans-Carboniferous/Permian
# * Keyling/Hyland Bay-Permian
# * Jurassic/Early Cretaceous-Mesozoic
# * Locker-Mungaroo/Barrow
# * Latrobe
# * Late Jurassic/Early Cretaceous-Mesozoic
# * Dingo-Mungaroo/Barrow

# %%
map.readshapefile('/content/SedBasinLabs/UoS/Lab1/Data/Oil_Gas_Outlines', 'Oil_Gas_Outlines',drawbounds = False)
# Out:
# (159,
#  5,
#  [-124.91465996898343, -54.719759923501535, 0.0, 0.0],
#  [149.11176087344734, 81.74520952345712, 0.0, 0.0])

# %%
## The first one has been done for you.
for info, shape in zip(map.Oil_Gas_Outlines_info, map.Oil_Gas_Outlines):
    if info['NAME'] == 'Milligans-Carboniferous/Permian':
        print (info['NAME'],info['O_G'],info['KWN_OIL'],info['KWN_GAS'])
# Out:
# Milligans-Carboniferous/Permian Oil 15 48

# %%
## You can add new cells by using the + button at the top of this window

# %% [markdown]
# ## Displaying Oil and Gas fields of Australia by Volume

# %% [markdown]
# Just like we did for the world we will now display the oil and gas fields of Australia graded by volume, to do this, we need the maximum value for both oil and gas, to display by log scale

# %%
rcParams['figure.figsize'] = (25,7)
fig     = plt.figure()
ax      = fig.add_subplot(111)

map = Basemap(llcrnrlon=100,llcrnrlat=-50,urcrnrlon=180,urcrnrlat=10.,
             resolution='l', projection='merc', lat_0 = 39.5, lon_0 = 1)

#map.drawmapboundary(fill_color='aqua')
map.fillcontinents(color='#C0C0C0') #,lake_color='aqua')
map.drawcoastlines()
map.drawparallels(np.arange(-80,81,20),labels=[1,0,0,0], fontsize=10)
map.drawmeridians(np.arange(-180,180,20),labels=[0,0,0,1], fontsize=10)
map.readshapefile('/content/SedBasinLabs/UoS/Lab1/Data/Oil_Gas_Outlines', 'Oil_Gas_Outlines',drawbounds = False)

#the readshapefile method allow you to call the shapefile's shapes and info.
#Both are lists, the first containing a list of tuples (coordinates), and the second containig a dictionary with associated metadata

oilmax = log(5000)
print (oilmax)

gasmax = log(10000)
print (gasmax)

for info, shape in zip(map.Oil_Gas_Outlines_info, map.Oil_Gas_Outlines):
    if info['O_G'] == 'Oil':
        if info['KWN_OIL']>0.:
            poly = Polygon(shape, facecolor=cm.YlGn(log(info['KWN_OIL'])/oilmax))
            plt.gca().add_patch(poly)
    if info['O_G'] == 'Gas':
        if info['KWN_GAS']>0.:
            poly = Polygon(shape, facecolor=cm.OrRd(log(info['KWN_GAS'])/gasmax))
            plt.gca().add_patch(poly)

#adds the colormap legend
cmleg = np.zeros((1,int(oilmax)))
for i in range(int(oilmax)):
    cmleg[0,i] = (i)
plt.imshow(cmleg, cmap=plt.get_cmap("YlGn"), aspect=1)
plt.colorbar()

#adds the colormap legend GAS
cmleg = np.zeros((1,int(gasmax)))
for i in range(int(gasmax)):
    cmleg[0,i] = (i)
plt.imshow(cmleg, cmap=plt.get_cmap("OrRd"), aspect=1)
plt.colorbar()

plt.show()
# Out:
# 8.517193191416238
# 9.210340371976184

# %% [markdown]
# ## Manqa Oil Field

# %%
for info, shape in zip(map.Oil_Gas_Outlines_info, map.Oil_Gas_Outlines):
    if info['NAME'] == 'Maqna':
        print (info['NAME'],info['O_G'],info['KWN_OIL'],info['KWN_GAS'])
# Out:
# Maqna Oil 155 3527
# Maqna Oil 155 3527

# %% [markdown]
# Zoom in on the Manqa oil province in the Red Sea. What do you notice about its geometry? Can you hypothesize the tectonic origin of this oil field?

# %%
## Make a map of the region here!

# %% [markdown]
# ## Calculating OOIP & OGIP
# Volumetric estimates of OOIP (original oil in place) and OGIP (original gas in place) are based on a geological model that geometrically describes the volume of hydrocarbons in the reservoir. However, due mainly to gas evolving from the oil as pressure and temperature are decreased, oil at the surface occupies less space than it does in the subsurface. Conversely, gas at the surface occupies more space than it does in the subsurface because of expansion. This necessitates correcting subsurface volumes to standard units of volume measured at surface conditions.
# One basic volumetric equation is
#
# N = [7758*a*h*ø*(1-Sw)]/Boi
#
# Where;
# * N = OOIP (STB, stock tank barrels)
# * 7758 = conversion factor from acre-ft to bbl
# * A = area of reservoir (acres) from map data
# * h = height or thickness of pay zone (ft) from log and/or core data
# * ø = porosity (decimal) from log and/or core data
# * Sw = connate water saturation (decimal) from log and/or core data
# * Boi = formation volume factor for oil at initial conditions (reservoir bbl/STB) from lab data
#
# Another basic volumetric equation is
#
# G = [43560*A*h*ø*(1-Sw)]/Bgi
#
# Where;
# * G = OGIP(SCF, standard cubic feet)
# * 43560 = conversion factor from acre-ft to ft3
# * Bgi = formation volume factor for gas at initial conditions (reservoir ft3/SCF)
#
# Recoverable reserves are a fraction of the OOIP or OGIP and are dependent on the efficiency of the reservoir drive mechanism. The basic equation used to calculate recoverable oil reserves is OOIP multiplied by a recovery factor (given to you by your reservoir engineers and dependent on the drive mechanism of the field)

# %%
## Example OOIP calculation - remember to be careful with your units
h=2
o=0.01
Sw=0.4
Bo =1.3
a = 120000

# %%
## Now I am going to define the OOIP function
def functionOOIP(a,h,o,Sw):

    OOIP = (7758 *a* h * o * (1-Sw))/Bo

    return OOIP

val = functionOOIP(a,h,o,Sw)/1000000 ## we usually report OOIP in MMCF, million CF
print (val)
# Out:
# 8.593476923076922

# %%
## You can define the OGIP function here!

# %% [markdown]
# ## Q7: Make a map of the La Trobe Oil field in Australia

# %%
## Make a map here!

# %%
## Back calculate the reservoir thickness of the field here!

# %% [markdown]
# ## `$$$$$$$$$$$`
